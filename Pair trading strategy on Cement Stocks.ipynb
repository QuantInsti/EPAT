# %% [markdown]
# # Mean Reversion Strategy on Cement Stocks

# %%
# Import the required libraries
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt  
# %matplotlib inline
plt.style.use('seaborn-darkgrid')

# %%
# Fix the backtesting period

end = pd.datetime.now().date()
start = end - pd.Timedelta(days=3*252)
# Out:
# <ipython-input-2-f2b145e4c0bb>:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   end = pd.datetime.now().date()

# %%
# Create a class for backtesting pairs
class mean_reversion_pairs:
    
    # Create object attributes/methods
    def __init__(self,x,y,start,end,lookback,std_dev):
        
        self.x = x # Independent variable
        self.y = y # Dependent variable
        self.start =start 
        self.end = end
        self.lookback = lookback # Lookback period to consider moving average
        self.std_dev = std_dev # Number of standard deivations away to create bollinger band
        
        self.fetch_data()
        self.hedge_ratio()
        self.ADFtest()
        self.indicators()
        self.positions()
        self.returns()
        self.calc_drawdown()
        
    # To fetch the data from yahoo finance for both stocks x and y
    def fetch_data(self):
        
        self.dfx = yf.download(self.x,start,end)
        self.dfy = yf.download(self.y,start,end)
        
        # Create a single dataframe to concat only the closing prices for backtesting purpose
        self.df = pd.concat([self.dfx['Adj Close'],self.dfy['Adj Close']],axis=1)
        self.df.columns =[self.x,self.y]
        self.df.index = pd.to_datetime(self.df.index)
    
    # Calculate hedge ratio by running ordinary least square regression
    def hedge_ratio(self):
        import statsmodels.api as sm
        self.model = sm.OLS(self.df[self.y].iloc[:120],self.df[self.x].iloc[:120])
        self.model = self.model.fit()
        self.df['spread'] = self.df[self.y] - self.model.params[0] * self.df[self.x]
        return self.model.params[0]
    
    # Perform ADF test on the spread of the pair and return the T statistic value
    def ADFtest(self):
        from statsmodels.tsa.stattools import adfuller
        self.ADF = adfuller(self.df['spread'],maxlag=1)
        return self.ADF[0]
    
    # Compute the required indicators for bollinger band
    def indicators(self):
        
        # Moving Average
        self.df['moving_average'] = self.df['spread'].rolling(self.lookback,center=False).mean()
        
        # Moving Standard Deviation
        self.df['moving_std_dev'] = self.df['spread'].rolling(self.lookback,center=False).std()

        # Upper band and lower band
        self.df['upper_band'] = self.df['moving_average'] + self.std_dev*self.df['moving_std_dev']
        self.df['lower_band'] = self.df['moving_average'] - self.std_dev*self.df['moving_std_dev']
    
    # Compute the positions based on the signal
    def positions(self):
        
        # Long positions
        self.df['long_entry'] = self.df['spread'] < self.df['lower_band']
        self.df['long_exit'] = self.df['spread'] >= self.df['moving_average']

        self.df['positions_long'] = np.nan
        self.df.loc[self.df['long_entry'], 'positions_long'] = 1
        self.df.loc[self.df['long_exit'], 'positions_long'] = 0
        self.df['positions_long'] = self.df['positions_long'].fillna(method='ffill')

        # Short positions
        self.df['short_entry'] = self.df['spread'] > self.df['upper_band']
        self.df['short_exit'] = self.df['spread'] <= self.df['moving_average']

        self.df['positions_short'] = np.nan
        self.df.loc[self.df['short_entry'], 'positions_short'] = -1
        self.df.loc[self.df['short_exit'], 'positions_short'] = 0
        self.df['positions_short'] = self.df['positions_short'].fillna(method='ffill')
        
        # Positions
        self.df['positions'] = self.df['positions_long'] + self.df['positions_short']
    
    # Calculate the strategy returns
    def returns(self):
        
        self.df['percentage_change'] = (self.df['spread'] - self.df['spread'].shift(1))/(self.model.params[0]*self.df[self.x] + self.df[self.y])
        self.df['strategy_returns'] = self.df['positions'].shift(1) * self.df['percentage_change']
        self.df['cumulative_returns'] = (self.df['strategy_returns']+1).cumprod()
        print("The total strategy returns are " ,((self.df['cumulative_returns'].iloc[-1]-1)*100))
        return (self.df['cumulative_returns'].iloc[-1]-1)*100
    
    # Calculate the max drawdown of the returns
    def calc_drawdown(self):
        # Calculate the running maximum
        self.running_max = np.maximum.accumulate(self.df['cumulative_returns'].dropna())
        # Ensure the value never drops below 1
        self.running_max[self.running_max < 1] = 1
        # Calculate the percentage drawdown
        self.drawdown = (self.df['cumulative_returns'])/self.running_max - 1
        return self.drawdown.min()*100

# %%
# Run the strategy by considering different cement stocks of same cap with different look back period and number of standard deviations away from the mean
Stocks_X_list = ['ULTRACEMCO.NS','GRASIM.NS','SHREECEM.NS','AMBUJACEM.NS','ACC.NS','JKCEMENT.NS','RAMCOCEM.NS']
Stocks_Y_list = ['ULTRACEMCO.NS','GRASIM.NS','SHREECEM.NS','AMBUJACEM.NS','ACC.NS','JKCEMENT.NS','RAMCOCEM.NS']

X=[]
Y=[]

lookback_list =range(5,25,5)
stdev_list = [1,1.5,2,2.5]

lookbackperiod =[]
stdev_range = []
Hedge_ratio = []
ADF_Tstat = []
Strat_Returns = []
Drawdown = []

for i in Stocks_X_list:
    for j in Stocks_Y_list:
        for k in lookback_list:
            for l in stdev_list:
                if i == j:
                    continue
                else:
                
            
                    Pairs = mean_reversion_pairs(i,j,start,end,k,l)
                    X.append(i)
                    Y.append(j)
                    lookbackperiod.append(k)
                    stdev_range.append(l)
                    Hedge_ratio.append(Pairs.hedge_ratio())
                    ADF_Tstat.append(Pairs.ADFtest())
                    Strat_Returns.append(Pairs.returns())
                    Drawdown.append(Pairs.calc_drawdown())
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  2.911888022654008
# The total strategy returns are  2.911888022654008
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  9.481955526441999
# The total strategy returns are  9.481955526441999
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  15.264974077552917
# The total strategy returns are  15.264974077552917
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  32.199081344003666
# The total strategy returns are  32.199081344003666
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  8.742792651671817
# The total strategy returns are  8.742792651671817
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  1.4119348471711035
# The total strategy returns are  1.4119348471711035
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  19.85921549514149
# The total strategy returns are  19.85921549514149
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  21.93583176907159
# The total strategy returns are  21.93583176907159
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -0.8798011143595796
# The total strategy returns are  -0.8798011143595796
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  2.8718275465377863
# The total strategy returns are  2.8718275465377863
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  12.696825880118979
# The total strategy returns are  12.696825880118979
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  5.979961671643563
# The total strategy returns are  5.979961671643563
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  4.0845249513675075
# The total strategy returns are  4.0845249513675075
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  1.304165204072305
# The total strategy returns are  1.304165204072305
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  15.138615157505786
# The total strategy returns are  15.138615157505786
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  13.29684542431413
# The total strategy returns are  13.29684542431413
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.8774814583214052
# The total strategy returns are  0.8774814583214052
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  10.624881950394439
# The total strategy returns are  10.624881950394439
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -1.5086345695554781
# The total strategy returns are  -1.5086345695554781
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  1.308315490839762
# The total strategy returns are  1.308315490839762
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -4.098927954936727
# The total strategy returns are  -4.098927954936727
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -9.423510557798531
# The total strategy returns are  -9.423510557798531
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -12.014041339943448
# The total strategy returns are  -12.014041339943448
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -9.548646476058876
# The total strategy returns are  -9.548646476058876
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -2.766187687015953
# The total strategy returns are  -2.766187687015953
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -7.267063698595189
# The total strategy returns are  -7.267063698595189
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.5750601884507711
# The total strategy returns are  0.5750601884507711
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -3.1782410624357604
# The total strategy returns are  -3.1782410624357604
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  68.98432015760316
# The total strategy returns are  68.98432015760316
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  26.728584888401997
# The total strategy returns are  26.728584888401997
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  63.414148082471215
# The total strategy returns are  63.414148082471215
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  49.94722065934647
# The total strategy returns are  49.94722065934647
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  16.712663421714204
# The total strategy returns are  16.712663421714204
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  2.657741251481127
# The total strategy returns are  2.657741251481127
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  47.573983055642
# The total strategy returns are  47.573983055642
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  33.43607998157445
# The total strategy returns are  33.43607998157445
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  32.617307634709356
# The total strategy returns are  32.617307634709356
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  10.498632499869798
# The total strategy returns are  10.498632499869798
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  48.60453787726069
# The total strategy returns are  48.60453787726069
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  38.19276384046051
# The total strategy returns are  38.19276384046051
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  15.33769018470057
# The total strategy returns are  15.33769018470057
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  19.198736344528466
# The total strategy returns are  19.198736344528466
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  50.89976693904741
# The total strategy returns are  50.89976693904741
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  28.085791942552962
# The total strategy returns are  28.085791942552962
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  50.27989157003769
# The total strategy returns are  50.27989157003769
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  32.3381438242822
# The total strategy returns are  32.3381438242822
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  8.7367116659421
# The total strategy returns are  8.7367116659421
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.12753509996028534
# The total strategy returns are  0.12753509996028534
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  56.31688965626807
# The total strategy returns are  56.31688965626807
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  46.55603726645863
# The total strategy returns are  46.55603726645863
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  22.33317499223162
# The total strategy returns are  22.33317499223162
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  11.494623325586527
# The total strategy returns are  11.494623325586527
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  45.023100661035656
# The total strategy returns are  45.023100661035656
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  29.73556781327329
# The total strategy returns are  29.73556781327329
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  33.250725773571446
# The total strategy returns are  33.250725773571446
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  16.596373109816497
# The total strategy returns are  16.596373109816497
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  45.93446060320987
# The total strategy returns are  45.93446060320987
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  15.276510230811112
# The total strategy returns are  15.276510230811112
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  86.10317409850327
# The total strategy returns are  86.10317409850327
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  90.27665993889218
# The total strategy returns are  90.27665993889218
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  43.61223946892861
# The total strategy returns are  43.61223946892861
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  7.539477313672394
# The total strategy returns are  7.539477313672394
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  94.15812832991965
# The total strategy returns are  94.15812832991965
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  73.70615016173616
# The total strategy returns are  73.70615016173616
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  82.16907838998013
# The total strategy returns are  82.16907838998013
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  18.98707169223366
# The total strategy returns are  18.98707169223366
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  106.64209368394997
# The total strategy returns are  106.64209368394997
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  114.82384068764983
# The total strategy returns are  114.82384068764983
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  62.39213630798677
# The total strategy returns are  62.39213630798677
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  40.6129066783768
# The total strategy returns are  40.6129066783768
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  11.818511341658876
# The total strategy returns are  11.818511341658876
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  13.313108952546004
# The total strategy returns are  13.313108952546004
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  21.802045580604368
# The total strategy returns are  21.802045580604368
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  24.88536986196315
# The total strategy returns are  24.88536986196315
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  9.19056472564872
# The total strategy returns are  9.19056472564872
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.3852109897904299
# The total strategy returns are  0.3852109897904299
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  15.581605282843514
# The total strategy returns are  15.581605282843514
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  8.258799303781528
# The total strategy returns are  8.258799303781528
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -3.5925311865141363
# The total strategy returns are  -3.5925311865141363
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  10.09095351781706
# The total strategy returns are  10.09095351781706
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  19.502916664490243
# The total strategy returns are  19.502916664490243
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  4.745256205899695
# The total strategy returns are  4.745256205899695
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -4.010761213209591
# The total strategy returns are  -4.010761213209591
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  6.128517764332186
# The total strategy returns are  6.128517764332186
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  3.364824081011908
# The total strategy returns are  3.364824081011908
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  9.559145446265793
# The total strategy returns are  9.559145446265793
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  15.381238022767452
# The total strategy returns are  15.381238022767452
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  32.2228017982146
# The total strategy returns are  32.2228017982146
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  8.711559524160961
# The total strategy returns are  8.711559524160961
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  1.4029701911245196
# The total strategy returns are  1.4029701911245196
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  18.34519693151733
# The total strategy returns are  18.34519693151733
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  22.02297461453009
# The total strategy returns are  22.02297461453009
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  3.7957500723995174
# The total strategy returns are  3.7957500723995174
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  2.895768098446494
# The total strategy returns are  2.895768098446494
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  14.766595764967082
# The total strategy returns are  14.766595764967082
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  6.068418226473216
# The total strategy returns are  6.068418226473216
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  4.126924720404035
# The total strategy returns are  4.126924720404035
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  1.285914873576255
# The total strategy returns are  1.285914873576255
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -13.546270816233829
# The total strategy returns are  -13.546270816233829
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -9.311181353779963
# The total strategy returns are  -9.311181353779963
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -22.18453538624351
# The total strategy returns are  -22.18453538624351
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -24.090191985279375
# The total strategy returns are  -24.090191985279375
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -10.723078169911549
# The total strategy returns are  -10.723078169911549
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -14.994242634326206
# The total strategy returns are  -14.994242634326206
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -12.911259038268652
# The total strategy returns are  -12.911259038268652
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -11.16980981615785
# The total strategy returns are  -11.16980981615785
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -17.691697877741763
# The total strategy returns are  -17.691697877741763
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -14.336462441006626
# The total strategy returns are  -14.336462441006626
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -11.443361428825893
# The total strategy returns are  -11.443361428825893
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -12.903133202474148
# The total strategy returns are  -12.903133202474148
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -11.169441332894625
# The total strategy returns are  -11.169441332894625
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  17.732858376563996
# The total strategy returns are  17.732858376563996
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  21.227317012610513
# The total strategy returns are  21.227317012610513
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  3.663924741312341
# The total strategy returns are  3.663924741312341
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -3.966914047781067
# The total strategy returns are  -3.966914047781067
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  7.160426353512128
# The total strategy returns are  7.160426353512128
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -1.5567927629206113
# The total strategy returns are  -1.5567927629206113
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -5.363606808589005
# The total strategy returns are  -5.363606808589005
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -4.789084938152854
# The total strategy returns are  -4.789084938152854
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  7.430295495006023
# The total strategy returns are  7.430295495006023
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -22.12030021553152
# The total strategy returns are  -22.12030021553152
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -20.75742845787918
# The total strategy returns are  -20.75742845787918
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -19.67440182412572
# The total strategy returns are  -19.67440182412572
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -2.318883758798118
# The total strategy returns are  -2.318883758798118
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  2.678306515890805
# The total strategy returns are  2.678306515890805
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  1.941371280508264
# The total strategy returns are  1.941371280508264
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -7.764607798061451
# The total strategy returns are  -7.764607798061451
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  2.2692192605625383
# The total strategy returns are  2.2692192605625383
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -10.000653514317248
# The total strategy returns are  -10.000653514317248
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  1.849446740028604
# The total strategy returns are  1.849446740028604
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -7.039337264039347
# The total strategy returns are  -7.039337264039347
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -0.03994198973510388
# The total strategy returns are  -0.03994198973510388
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -13.812428039885427
# The total strategy returns are  -13.812428039885427
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -1.0091777160912474
# The total strategy returns are  -1.0091777160912474
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -14.869368599456745
# The total strategy returns are  -14.869368599456745
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -16.685395054059438
# The total strategy returns are  -16.685395054059438
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -11.709652312751729
# The total strategy returns are  -11.709652312751729
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -14.271316191449179
# The total strategy returns are  -14.271316191449179
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  34.31543900694252
# The total strategy returns are  34.31543900694252
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -5.4457701584062495
# The total strategy returns are  -5.4457701584062495
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  60.49291311250775
# The total strategy returns are  60.49291311250775
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  29.840282522375936
# The total strategy returns are  29.840282522375936
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  22.79985126048516
# The total strategy returns are  22.79985126048516
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  4.498762461828498
# The total strategy returns are  4.498762461828498
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  43.499540434887194
# The total strategy returns are  43.499540434887194
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  38.536299605970534
# The total strategy returns are  38.536299605970534
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  37.96046925547576
# The total strategy returns are  37.96046925547576
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  12.837449464310978
# The total strategy returns are  12.837449464310978
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  68.36291482852333
# The total strategy returns are  68.36291482852333
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  52.54538987480797
# The total strategy returns are  52.54538987480797
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  38.98552228269034
# The total strategy returns are  38.98552228269034
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  12.456268732174136
# The total strategy returns are  12.456268732174136
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  30.042714776646417
# The total strategy returns are  30.042714776646417
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  1.9835860114471249
# The total strategy returns are  1.9835860114471249
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  16.76518231152311
# The total strategy returns are  16.76518231152311
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  12.09031147700992
# The total strategy returns are  12.09031147700992
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  7.701165385324238
# The total strategy returns are  7.701165385324238
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  1.6190551574230438
# The total strategy returns are  1.6190551574230438
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  38.92546876932037
# The total strategy returns are  38.92546876932037
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  34.08088914140326
# The total strategy returns are  34.08088914140326
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  10.147479194000098
# The total strategy returns are  10.147479194000098
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  11.039356230310648
# The total strategy returns are  11.039356230310648
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  26.1805590112369
# The total strategy returns are  26.1805590112369
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  14.631151975369082
# The total strategy returns are  14.631151975369082
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  15.241848691447203
# The total strategy returns are  15.241848691447203
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  20.784942657829085
# The total strategy returns are  20.784942657829085
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  14.782825347737027
# The total strategy returns are  14.782825347737027
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  13.32043367989768
# The total strategy returns are  13.32043367989768
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  3.610043848970479
# The total strategy returns are  3.610043848970479
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  13.650089400283427
# The total strategy returns are  13.650089400283427
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -1.5379892596513955
# The total strategy returns are  -1.5379892596513955
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  1.3042086439688738
# The total strategy returns are  1.3042086439688738
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -4.133742328555046
# The total strategy returns are  -4.133742328555046
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -9.238152134214106
# The total strategy returns are  -9.238152134214106
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -12.055366807646205
# The total strategy returns are  -12.055366807646205
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -9.575174818131515
# ...
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  26.170898922535414
# The total strategy returns are  26.170898922535414
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  14.625544228405385
# The total strategy returns are  14.625544228405385
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  15.256756610036536
# The total strategy returns are  15.256756610036536
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  20.76516928237353
# The total strategy returns are  20.76516928237353
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  64.82526795776484
# The total strategy returns are  64.82526795776484
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  18.834565929448654
# The total strategy returns are  18.834565929448654
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  23.78451546618985
# The total strategy returns are  23.78451546618985
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  30.84952709649933
# The total strategy returns are  30.84952709649933
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  13.258991173570788
# The total strategy returns are  13.258991173570788
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  25.84074734029038
# The total strategy returns are  25.84074734029038
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  19.416393091165098
# The total strategy returns are  19.416393091165098
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  7.079902300701613
# The total strategy returns are  7.079902300701613
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  4.538616711727483
# The total strategy returns are  4.538616711727483
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  16.494272441617053
# The total strategy returns are  16.494272441617053
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  6.916552977171397
# The total strategy returns are  6.916552977171397
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  4.817597084664671
# The total strategy returns are  4.817597084664671
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  9.75165559093516
# The total strategy returns are  9.75165559093516
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  64.4279941516525
# The total strategy returns are  64.4279941516525
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  37.42754463225102
# The total strategy returns are  37.42754463225102
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  41.10067251098619
# The total strategy returns are  41.10067251098619
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  10.363867675585258
# The total strategy returns are  10.363867675585258
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -1.6461498439441002
# The total strategy returns are  -1.6461498439441002
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  1.8262188665756351
# The total strategy returns are  1.8262188665756351
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  11.749540449827855
# The total strategy returns are  11.749540449827855
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  4.480156882581343
# The total strategy returns are  4.480156882581343
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  4.847892562423106
# The total strategy returns are  4.847892562423106
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -9.274862364345903
# The total strategy returns are  -9.274862364345903
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  5.809167719860797
# The total strategy returns are  5.809167719860797
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  1.7700745469494183
# The total strategy returns are  1.7700745469494183
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -4.6295686303078565
# The total strategy returns are  -4.6295686303078565
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -0.716132321357299
# The total strategy returns are  -0.716132321357299
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -3.249324171313339
# The total strategy returns are  -3.249324171313339
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  10.028956512077958
# The total strategy returns are  10.028956512077958
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -7.881381711433145
# The total strategy returns are  -7.881381711433145
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -9.71284095328696
# The total strategy returns are  -9.71284095328696
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -4.436503822121473
# The total strategy returns are  -4.436503822121473
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -8.517959693341526
# The total strategy returns are  -8.517959693341526
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -5.542601870586072
# The total strategy returns are  -5.542601870586072
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -10.418397756515919
# The total strategy returns are  -10.418397756515919
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -14.792795599211118
# The total strategy returns are  -14.792795599211118
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -6.752075700503635
# The total strategy returns are  -6.752075700503635
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -10.507144866654494
# The total strategy returns are  -10.507144866654494
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -14.203611137113082
# The total strategy returns are  -14.203611137113082
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -10.443843650266482
# The total strategy returns are  -10.443843650266482
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -10.509320462973193
# The total strategy returns are  -10.509320462973193
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  78.162250041268
# The total strategy returns are  78.162250041268
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  44.69913877773792
# The total strategy returns are  44.69913877773792
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  59.64564399111205
# The total strategy returns are  59.64564399111205
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  53.83041475402464
# The total strategy returns are  53.83041475402464
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  40.61667746777724
# The total strategy returns are  40.61667746777724
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  3.416399121821456
# The total strategy returns are  3.416399121821456
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  74.98856794164412
# The total strategy returns are  74.98856794164412
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  81.01115322520522
# The total strategy returns are  81.01115322520522
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  72.26976261074137
# The total strategy returns are  72.26976261074137
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  21.574506853149856
# The total strategy returns are  21.574506853149856
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  79.50130897921998
# The total strategy returns are  79.50130897921998
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  76.2944408317641
# The total strategy returns are  76.2944408317641
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  80.28477455074652
# The total strategy returns are  80.28477455074652
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  36.44608605168869
# The total strategy returns are  36.44608605168869

# %%
# Convert the results in to dataframe for validation
Pair_Strategy = pd.DataFrame({'Stock_X':X,'Stock_Y':Y,'Lookback' :lookbackperiod,'Std dev':stdev_range,'Hedge_Ratio':Hedge_ratio,'ADF Tstat': ADF_Tstat,'Strategy Returns':Strat_Returns,'Max Drawdown': Drawdown})

# %%
# Sort the dataframe based on highest returns
Pair_Strategy.sort_values(by='Strategy Returns',ascending=False)
# Out:
#            Stock_X        Stock_Y  Lookback  Std dev  Hedge_Ratio  ADF Tstat  \
# 77   ULTRACEMCO.NS    JKCEMENT.NS        20      1.5     0.318068  -1.758021
# 493    JKCEMENT.NS  ULTRACEMCO.NS        20      1.5     3.128475  -1.770150
# 76   ULTRACEMCO.NS    JKCEMENT.NS        20      1.0     0.318068  -1.758021
# 492    JKCEMENT.NS  ULTRACEMCO.NS        20      1.0     3.128475  -1.770149
# 536    JKCEMENT.NS   AMBUJACEM.NS        15      1.0     0.141418  -2.007898
# ..             ...            ...       ...      ...          ...        ...
# 140      GRASIM.NS   AMBUJACEM.NS        20      1.0     0.279838  -0.843761
# 116      GRASIM.NS    SHREECEM.NS        10      1.0    34.271740   0.199905
# 212    SHREECEM.NS      GRASIM.NS        10      1.0     0.028948   0.199868
# 117      GRASIM.NS    SHREECEM.NS        10      1.5    34.271740   0.199905
# 213    SHREECEM.NS      GRASIM.NS        10      1.5     0.028948   0.199869
#
#      Strategy Returns  Max Drawdown
# 77         114.823841     -8.441719
# 493        114.503347     -8.420070
# 76         106.642094     -9.636713
# 492        106.217566     -9.610658
# 536         97.537535     -7.620643
# ..                ...           ...
# 140        -22.120300    -29.643283
# 116        -22.184535    -28.899140
# 212        -22.494977    -29.163860
# 117        -24.090192    -27.685352
# 213        -24.426165    -28.028381
#
# [672 rows x 8 columns]
