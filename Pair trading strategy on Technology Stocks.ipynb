# %% [markdown]
# # Mean Reversion Strategy on Technology Stocks

# %%
# Import the required libraries
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt  
# %matplotlib inline
plt.style.use('seaborn-darkgrid')

# %%
# Fix the backtesting period

end = pd.datetime.now().date()
start = end - pd.Timedelta(days=1*252)
# Out:
# <ipython-input-2-547ee0215d57>:3: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   end = pd.datetime.now().date()

# %%
# Create a class for backtesting pairs
class mean_reversion_pairs:
    
    # Create object attributes/methods
    def __init__(self,x,y,start,end,lookback,std_dev):
        
        self.x = x # Independent variable
        self.y = y # Dependent variable
        self.start =start 
        self.end = end
        self.lookback = lookback # Lookback period to consider moving average
        self.std_dev = std_dev # Number of standard deivations away to create bollinger band
        
        self.fetch_data()
        self.hedge_ratio()
        self.ADFtest()
        self.indicators()
        self.positions()
        self.returns()
        self.calc_drawdown()
        
    # To fetch the data from yahoo finance for both stocks x and y
    def fetch_data(self):
        
        self.dfx = yf.download(self.x,start,end)
        self.dfy = yf.download(self.y,start,end)
        
        # Create a single dataframe to concat only the closing prices for backtesting purpose
        self.df = pd.concat([self.dfx['Adj Close'],self.dfy['Adj Close']],axis=1)
        self.df.columns =[self.x,self.y]
        self.df.index = pd.to_datetime(self.df.index)
    
    # Calculate hedge ratio by running ordinary least square regression
    def hedge_ratio(self):
        import statsmodels.api as sm
        self.model = sm.OLS(self.df[self.y].iloc[:120],self.df[self.x].iloc[:120])
        self.model = self.model.fit()
        self.df['spread'] = self.df[self.y] - self.model.params[0] * self.df[self.x]
        return self.model.params[0]
    
    # Perform ADF test on the spread of the pair and return the T statistic value
    def ADFtest(self):
        from statsmodels.tsa.stattools import adfuller
        self.ADF = adfuller(self.df['spread'],maxlag=1)
        return self.ADF[0]
    
    # Compute the required indicators for bollinger band
    def indicators(self):
        
        # Moving Average
        self.df['moving_average'] = self.df['spread'].rolling(self.lookback,center=False).mean()
        
        # Moving Standard Deviation
        self.df['moving_std_dev'] = self.df['spread'].rolling(self.lookback,center=False).std()

        # Upper band and lower band
        self.df['upper_band'] = self.df['moving_average'] + self.std_dev*self.df['moving_std_dev']
        self.df['lower_band'] = self.df['moving_average'] - self.std_dev*self.df['moving_std_dev']
    
    # Compute the positions based on the signal
    def positions(self):
        
        # Long positions
        self.df['long_entry'] = self.df['spread'] < self.df['lower_band']
        self.df['long_exit'] = self.df['spread'] >= self.df['moving_average']

        self.df['positions_long'] = np.nan
        self.df.loc[self.df['long_entry'], 'positions_long'] = 1
        self.df.loc[self.df['long_exit'], 'positions_long'] = 0
        self.df['positions_long'] = self.df['positions_long'].fillna(method='ffill')

        # Short positions
        self.df['short_entry'] = self.df['spread'] > self.df['upper_band']
        self.df['short_exit'] = self.df['spread'] <= self.df['moving_average']

        self.df['positions_short'] = np.nan
        self.df.loc[self.df['short_entry'], 'positions_short'] = -1
        self.df.loc[self.df['short_exit'], 'positions_short'] = 0
        self.df['positions_short'] = self.df['positions_short'].fillna(method='ffill')
        
        # Positions
        self.df['positions'] = self.df['positions_long'] + self.df['positions_short']
    
    # Calculate the strategy returns
    def returns(self):
        
        self.df['percentage_change'] = (self.df['spread'] - self.df['spread'].shift(1))/(self.model.params[0]*self.df[self.x] + self.df[self.y])
        self.df['strategy_returns'] = self.df['positions'].shift(1) * self.df['percentage_change']
        self.df['cumulative_returns'] = (self.df['strategy_returns']+1).cumprod()
        print("The total strategy returns are " ,((self.df['cumulative_returns'].iloc[-1]-1)*100))
        return (self.df['cumulative_returns'].iloc[-1]-1)*100
    
    # Calculate the max drawdown of the returns
    def calc_drawdown(self):
        # Calculate the running maximum
        self.running_max = np.maximum.accumulate(self.df['cumulative_returns'].dropna())
        # Ensure the value never drops below 1
        self.running_max[self.running_max < 1] = 1
        # Calculate the percentage drawdown
        self.drawdown = (self.df['cumulative_returns'])/self.running_max - 1
        return self.drawdown.min()*100

# %%
# Run the strategy by considering different Technology stocks of same cap with different look back period and number of standard deviations away from the mean
Stocks_X_list = ['TCS.NS','INFY.NS','HCLTECH.NS','WIPRO.NS','TECHM.NS','LTI.NS','MINDTREE.NS']
Stocks_Y_list = ['TCS.NS','INFY.NS','HCLTECH.NS','WIPRO.NS','TECHM.NS','LTI.NS','MINDTREE.NS']

X=[]
Y=[]

lookback_list =range(5,25,5)
stdev_list = [1,1.5,2,2.5]

lookbackperiod =[]
stdev_range = []
Hedge_ratio = []
ADF_Tstat = []
Strat_Returns = []
Drawdown = []

for i in Stocks_X_list:
    for j in Stocks_Y_list:
        for k in lookback_list:
            for l in stdev_list:
                if i == j:
                    continue
                else:
                
            
                    Pairs = mean_reversion_pairs(i,j,start,end,k,l)
                    X.append(i)
                    Y.append(j)
                    lookbackperiod.append(k)
                    stdev_range.append(l)
                    Hedge_ratio.append(Pairs.hedge_ratio())
                    ADF_Tstat.append(Pairs.ADFtest())
                    Strat_Returns.append(Pairs.returns())
                    Drawdown.append(Pairs.calc_drawdown())
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -10.944519174982414
# The total strategy returns are  -10.944519174982414
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -10.56694842531366
# The total strategy returns are  -10.56694842531366
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -13.847477843697142
# The total strategy returns are  -13.847477843697142
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -12.82465203648443
# The total strategy returns are  -12.82465203648443
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -12.498056434120585
# The total strategy returns are  -12.498056434120585
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -12.060546452229449
# The total strategy returns are  -12.060546452229449
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -10.155731465845431
# The total strategy returns are  -10.155731465845431
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -5.820438851441024
# The total strategy returns are  -5.820438851441024
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -6.007806162990059
# The total strategy returns are  -6.007806162990059
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -5.853660235172809
# The total strategy returns are  -5.853660235172809
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -6.9246153067640925
# The total strategy returns are  -6.9246153067640925
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -7.149286800739563
# The total strategy returns are  -7.149286800739563
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -3.416803260926704
# The total strategy returns are  -3.416803260926704
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  3.5066680267796135
# The total strategy returns are  3.5066680267796135
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -1.128642583660222
# The total strategy returns are  -1.128642583660222
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  5.493246947547203
# The total strategy returns are  5.493246947547203
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -3.0721694348371797
# The total strategy returns are  -3.0721694348371797
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  2.1273565093870017
# The total strategy returns are  2.1273565093870017
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  2.9852116808019913
# The total strategy returns are  2.9852116808019913
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.744620836445975
# The total strategy returns are  0.744620836445975
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -1.1367746846200233
# The total strategy returns are  -1.1367746846200233
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  1.6672677717549211
# The total strategy returns are  1.6672677717549211
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  1.4871778263769952
# The total strategy returns are  1.4871778263769952
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -1.383171306615516
# The total strategy returns are  -1.383171306615516
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -5.317542383965057
# The total strategy returns are  -5.317542383965057
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -2.6763681168751607
# The total strategy returns are  -2.6763681168751607
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  2.5090427376843083
# The total strategy returns are  2.5090427376843083
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -12.658678998410721
# The total strategy returns are  -12.658678998410721
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -9.429753450125089
# The total strategy returns are  -9.429753450125089
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -18.804914881754854
# The total strategy returns are  -18.804914881754854
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -20.28600869256025
# The total strategy returns are  -20.28600869256025
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -15.058652149180729
# The total strategy returns are  -15.058652149180729
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -2.6090887075141955
# The total strategy returns are  -2.6090887075141955
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -16.04980267774463
# The total strategy returns are  -16.04980267774463
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -9.901452511170083
# The total strategy returns are  -9.901452511170083
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -10.76170450097279
# The total strategy returns are  -10.76170450097279
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -7.50525766514224
# The total strategy returns are  -7.50525766514224
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -7.016691653287266
# The total strategy returns are  -7.016691653287266
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -7.5813976033496715
# The total strategy returns are  -7.5813976033496715
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -4.901555854784123
# The total strategy returns are  -4.901555854784123
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -3.1742052883417915
# The total strategy returns are  -3.1742052883417915
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -7.057053724041717
# The total strategy returns are  -7.057053724041717
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -6.472353711252088
# The total strategy returns are  -6.472353711252088
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -15.90231556275381
# The total strategy returns are  -15.90231556275381
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -15.840674097952935
# The total strategy returns are  -15.840674097952935
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -15.489616481192659
# The total strategy returns are  -15.489616481192659
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -13.765937109572747
# The total strategy returns are  -13.765937109572747
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -15.91718146094897
# The total strategy returns are  -15.91718146094897
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -12.82423105255005
# The total strategy returns are  -12.82423105255005
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -4.483750089828408
# The total strategy returns are  -4.483750089828408
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -14.667623823260145
# The total strategy returns are  -14.667623823260145
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -14.309136808059087
# The total strategy returns are  -14.309136808059087
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -16.764583385792708
# The total strategy returns are  -16.764583385792708
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -6.0858328658129786
# The total strategy returns are  -6.0858328658129786
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.05740908323552674
# The total strategy returns are  0.05740908323552674
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -6.107190920498118
# The total strategy returns are  -6.107190920498118
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -24.000139259871567
# The total strategy returns are  -24.000139259871567
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -23.80789865034677
# The total strategy returns are  -23.80789865034677
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -17.454843236445516
# The total strategy returns are  -17.454843236445516
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  2.66910590547067
# The total strategy returns are  2.66910590547067
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -22.170493957278246
# The total strategy returns are  -22.170493957278246
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -18.629195096121354
# The total strategy returns are  -18.629195096121354
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -18.811811457041905
# The total strategy returns are  -18.811811457041905
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -3.1337788860571147
# The total strategy returns are  -3.1337788860571147
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -17.84027438984481
# The total strategy returns are  -17.84027438984481
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -17.312322970764203
# The total strategy returns are  -17.312322970764203
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -15.702223839534856
# The total strategy returns are  -15.702223839534856
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -4.537612137980462
# The total strategy returns are  -4.537612137980462
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -10.345861085775631
# The total strategy returns are  -10.345861085775631
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  6.5009055653050485
# The total strategy returns are  6.5009055653050485
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -16.002123011405413
# The total strategy returns are  -16.002123011405413
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -23.16933014219591
# The total strategy returns are  -23.16933014219591
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -18.632765079799785
# The total strategy returns are  -18.632765079799785
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  2.059003179521013
# The total strategy returns are  2.059003179521013
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -20.929258463766054
# The total strategy returns are  -20.929258463766054
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -22.919194829947365
# The total strategy returns are  -22.919194829947365
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -19.763761718741957
# The total strategy returns are  -19.763761718741957
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -4.021314782692864
# The total strategy returns are  -4.021314782692864
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -22.40679843304837
# The total strategy returns are  -22.40679843304837
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -22.030010828319668
# The total strategy returns are  -22.030010828319668
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -18.799927468705956
# The total strategy returns are  -18.799927468705956
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -9.176371544760409
# The total strategy returns are  -9.176371544760409
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -10.931571065296652
# The total strategy returns are  -10.931571065296652
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -10.557478110091157
# The total strategy returns are  -10.557478110091157
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -13.850737337226615
# The total strategy returns are  -13.850737337226615
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -12.830847250177557
# The total strategy returns are  -12.830847250177557
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -12.497290348876733
# The total strategy returns are  -12.497290348876733
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -12.051000677876711
# The total strategy returns are  -12.051000677876711
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -10.143410490453874
# The total strategy returns are  -10.143410490453874
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -5.810514871468553
# The total strategy returns are  -5.810514871468553
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -6.001347202932383
# The total strategy returns are  -6.001347202932383
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -5.8463997210442376
# The total strategy returns are  -5.8463997210442376
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -6.911424935674582
# The total strategy returns are  -6.911424935674582
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -7.144958793153977
# The total strategy returns are  -7.144958793153977
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -3.428013662206797
# The total strategy returns are  -3.428013662206797
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -1.4912693935795307
# The total strategy returns are  -1.4912693935795307
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -1.2023602012289247
# The total strategy returns are  -1.2023602012289247
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -10.054400655034701
# The total strategy returns are  -10.054400655034701
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -10.98621419305308
# The total strategy returns are  -10.98621419305308
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -1.6222884103276103
# The total strategy returns are  -1.6222884103276103
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  3.048868747481226
# The total strategy returns are  3.048868747481226
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -6.634610185757406
# The total strategy returns are  -6.634610185757406
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -8.830104500861502
# The total strategy returns are  -8.830104500861502
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -3.27081803439796
# The total strategy returns are  -3.27081803439796
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  5.4782966342655115
# The total strategy returns are  5.4782966342655115
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -0.9500783819343939
# The total strategy returns are  -0.9500783819343939
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.31388534800518286
# The total strategy returns are  0.31388534800518286
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -3.0998425020699827
# The total strategy returns are  -3.0998425020699827
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -0.9906421564474632
# The total strategy returns are  -0.9906421564474632
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -10.340400881013101
# The total strategy returns are  -10.340400881013101
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  3.096188545898504
# The total strategy returns are  3.096188545898504
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -11.093439232603563
# The total strategy returns are  -11.093439232603563
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -10.051541752357462
# The total strategy returns are  -10.051541752357462
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -5.335991252637628
# The total strategy returns are  -5.335991252637628
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  1.5801256319502022
# The total strategy returns are  1.5801256319502022
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -8.25057164953974
# The total strategy returns are  -8.25057164953974
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -5.2973063160396405
# The total strategy returns are  -5.2973063160396405
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -2.9236986573939583
# The total strategy returns are  -2.9236986573939583
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  3.2827034649164366
# The total strategy returns are  3.2827034649164366
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -2.405460793421399
# The total strategy returns are  -2.405460793421399
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  1.0672565367476405
# The total strategy returns are  1.0672565367476405
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  3.341504802375983
# The total strategy returns are  3.341504802375983
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  1.0501963008067383
# The total strategy returns are  1.0501963008067383
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  7.373655329838158
# The total strategy returns are  7.373655329838158
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  1.3731449496806825
# The total strategy returns are  1.3731449496806825
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -6.370274717006219
# The total strategy returns are  -6.370274717006219
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -3.938704206098431
# The total strategy returns are  -3.938704206098431
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -9.686475207776034
# The total strategy returns are  -9.686475207776034
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -5.590436661289222
# The total strategy returns are  -5.590436661289222
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -10.545074280586542
# The total strategy returns are  -10.545074280586542
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -7.517698532166461
# The total strategy returns are  -7.517698532166461
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -7.610486753050982
# The total strategy returns are  -7.610486753050982
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -4.570099103077752
# The total strategy returns are  -4.570099103077752
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -11.505374634720301
# The total strategy returns are  -11.505374634720301
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -6.662918576808696
# The total strategy returns are  -6.662918576808696
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -7.668209687260408
# The total strategy returns are  -7.668209687260408
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -5.414586879321915
# The total strategy returns are  -5.414586879321915
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  7.390515622991822
# The total strategy returns are  7.390515622991822
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  3.943575609531469
# The total strategy returns are  3.943575609531469
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -0.05427594814436665
# The total strategy returns are  -0.05427594814436665
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -0.20631885030473196
# The total strategy returns are  -0.20631885030473196
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  7.281103073018613
# The total strategy returns are  7.281103073018613
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  1.4927196937923215
# The total strategy returns are  1.4927196937923215
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -0.8750693284187205
# The total strategy returns are  -0.8750693284187205
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -2.0440055541980695
# The total strategy returns are  -2.0440055541980695
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  4.270578751533294
# The total strategy returns are  4.270578751533294
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -6.467753426916756
# The total strategy returns are  -6.467753426916756
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.34334033391296703
# The total strategy returns are  0.34334033391296703
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  1.9716900546107086
# The total strategy returns are  1.9716900546107086
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -1.817214134404932
# The total strategy returns are  -1.817214134404932
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -4.899626198448869
# The total strategy returns are  -4.899626198448869
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -9.034109423391534
# The total strategy returns are  -9.034109423391534
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -3.1834346965480598
# The total strategy returns are  -3.1834346965480598
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -11.33484691566241
# The total strategy returns are  -11.33484691566241
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -13.001029186524438
# The total strategy returns are  -13.001029186524438
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -14.002471977713482
# The total strategy returns are  -14.002471977713482
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -8.494143444059443
# The total strategy returns are  -8.494143444059443
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -5.560347563795787
# The total strategy returns are  -5.560347563795787
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -8.310307757304159
# The total strategy returns are  -8.310307757304159
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -9.179973421491127
# The total strategy returns are  -9.179973421491127
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -7.222621363237103
# The total strategy returns are  -7.222621363237103
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -14.519810037245307
# The total strategy returns are  -14.519810037245307
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -17.232163829764403
# The total strategy returns are  -17.232163829764403
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -20.463238457493272
# The total strategy returns are  -20.463238457493272
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -18.191395539031063
# The total strategy returns are  -18.191395539031063
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  3.545454745532872
# The total strategy returns are  3.545454745532872
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -1.1065663372315404
# The total strategy returns are  -1.1065663372315404
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  5.507631227883714
# The total strategy returns are  5.507631227883714
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -3.061589247240848
# The total strategy returns are  -3.061589247240848
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  2.1507808711857646
# The total strategy returns are  2.1507808711857646
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  2.9801409413115376
# The total strategy returns are  2.9801409413115376
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.7618088330783923
# The total strategy returns are  0.7618088330783923
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -1.1162342654160606
# The total strategy returns are  -1.1162342654160606
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  1.699293978807792
# The total strategy returns are  1.699293978807792
# ...
# The total strategy returns are  -14.199223005155282
# The total strategy returns are  -14.199223005155282
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -16.89696732639926
# The total strategy returns are  -16.89696732639926
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -20.01308398654109
# The total strategy returns are  -20.01308398654109
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -16.56701238092172
# The total strategy returns are  -16.56701238092172
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  5.322326723589943
# The total strategy returns are  5.322326723589943
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  5.850985372585171
# The total strategy returns are  5.850985372585171
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -2.924737204607464
# The total strategy returns are  -2.924737204607464
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -5.527882188483546
# The total strategy returns are  -5.527882188483546
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -2.922410255625907
# The total strategy returns are  -2.922410255625907
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -2.4311868497872258
# The total strategy returns are  -2.4311868497872258
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -6.66497744369191
# The total strategy returns are  -6.66497744369191
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -6.50032106060171
# The total strategy returns are  -6.50032106060171
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -1.6389003072124542
# The total strategy returns are  -1.6389003072124542
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  2.669115897938812
# The total strategy returns are  2.669115897938812
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -12.050668830829947
# The total strategy returns are  -12.050668830829947
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -8.391304854852766
# The total strategy returns are  -8.391304854852766
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.17922525126947697
# The total strategy returns are  0.17922525126947697
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -0.5326897570055777
# The total strategy returns are  -0.5326897570055777
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  5.051495698605457
# The total strategy returns are  5.051495698605457
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  2.6840579856306945
# The total strategy returns are  2.6840579856306945
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  5.9154392361362
# The total strategy returns are  5.9154392361362
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  2.0790151073822427
# The total strategy returns are  2.0790151073822427
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -0.4997662271963521
# The total strategy returns are  -0.4997662271963521
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  1.6346361457504122
# The total strategy returns are  1.6346361457504122
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -4.095436564313992
# The total strategy returns are  -4.095436564313992
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -3.204371906850556
# The total strategy returns are  -3.204371906850556
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -0.005464979059721653
# The total strategy returns are  -0.005464979059721653
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  4.281097878754103
# The total strategy returns are  4.281097878754103
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -0.721491808319108
# The total strategy returns are  -0.721491808319108
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -4.6372166704839906
# The total strategy returns are  -4.6372166704839906
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -2.7055794676177136
# The total strategy returns are  -2.7055794676177136
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -3.1684756108877443
# The total strategy returns are  -3.1684756108877443
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -5.552025422547658
# The total strategy returns are  -5.552025422547658
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -8.281084679646767
# The total strategy returns are  -8.281084679646767
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -8.475073088730078
# The total strategy returns are  -8.475073088730078
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -5.699980059408272
# The total strategy returns are  -5.699980059408272
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -5.555133491438003
# The total strategy returns are  -5.555133491438003
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  5.372917638379082
# The total strategy returns are  5.372917638379082
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -8.938719247906057
# The total strategy returns are  -8.938719247906057
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -6.265340226327243
# The total strategy returns are  -6.265340226327243
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  2.744803710760646
# The total strategy returns are  2.744803710760646
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  1.3267693069457298
# The total strategy returns are  1.3267693069457298
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -7.8079414722209695
# The total strategy returns are  -7.8079414722209695
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -8.179474912505025
# The total strategy returns are  -8.179474912505025
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -2.9686538313480892
# The total strategy returns are  -2.9686538313480892
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  2.383396315727304
# The total strategy returns are  2.383396315727304
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  11.097594762694541
# The total strategy returns are  11.097594762694541
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  1.6117562727497647
# The total strategy returns are  1.6117562727497647
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  0.0
# The total strategy returns are  0.0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  18.413301955649565
# The total strategy returns are  18.413301955649565
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  12.469078585117588
# The total strategy returns are  12.469078585117588
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  7.1237566521929585
# The total strategy returns are  7.1237566521929585
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  4.650591639588497
# The total strategy returns are  4.650591639588497
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  14.241294385004299
# The total strategy returns are  14.241294385004299
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  3.272172087283498
# The total strategy returns are  3.272172087283498
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  4.444188363190804
# The total strategy returns are  4.444188363190804
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  -0.3712215897577531
# The total strategy returns are  -0.3712215897577531
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  9.039952008876352
# The total strategy returns are  9.039952008876352
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  7.711613508246162
# The total strategy returns are  7.711613508246162
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  9.51901788459013
# The total strategy returns are  9.51901788459013
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# The total strategy returns are  10.224779849319354
# The total strategy returns are  10.224779849319354

# %%
# Convert the results in to dataframe for validation
Pair_Strategy = pd.DataFrame({'Stock_X':X,'Stock_Y':Y,'Lookback' :lookbackperiod,'Std dev':stdev_range,'Hedge_Ratio':Hedge_ratio,'ADF Tstat': ADF_Tstat,'Strategy Returns':Strat_Returns,'Max Drawdown': Drawdown})

# %%
# Sort the dataframe based on highest returns
Pair_Strategy.sort_values(by='Strategy Returns',ascending=False)
# Out:
#          Stock_X      Stock_Y  Lookback  Std dev  Hedge_Ratio  ADF Tstat  \
# 548       LTI.NS     TECHM.NS        10      1.0     0.245210  -1.790653
# 452     TECHM.NS       LTI.NS        10      1.0     4.054203  -1.779989
# 365     WIPRO.NS       LTI.NS        20      1.5     8.594524  -1.146837
# 356     WIPRO.NS       LTI.NS        10      1.0     8.594524  -1.146837
# 532       LTI.NS     WIPRO.NS        10      1.0     0.114350  -1.135442
# ..           ...          ...       ...      ...          ...        ...
# 89        TCS.NS  MINDTREE.NS        15      1.5     1.025093  -1.380380
# 85        TCS.NS  MINDTREE.NS        10      1.5     1.025093  -1.380380
# 581  MINDTREE.NS       TCS.NS        10      1.5     0.933832  -1.365778
# 69        TCS.NS       LTI.NS        10      1.5     1.515608  -1.388292
# 68        TCS.NS       LTI.NS        10      1.0     1.515608  -1.388292
#
#      Strategy Returns  Max Drawdown
# 548         21.820915     -6.950147
# 452         21.780360     -6.920543
# 365         21.225403     -8.117199
# 356         21.024175     -8.117199
# 532         20.447428     -8.095813
# ..                ...           ...
# 89         -22.919195    -25.588215
# 85         -23.169330    -27.078599
# 581        -23.330120    -27.136478
# 69         -23.807899    -27.137946
# 68         -24.000139    -28.034297
#
# [672 rows x 8 columns]
